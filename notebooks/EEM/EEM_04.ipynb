# %%
using CSoM

# %%
l = 1.0       # Total length [m]
N = 5         # Number of nodes
els = N - 1   # Number of finite elements
nod = 2       # Number of nodes per finite elements
nodof = 1     # Degrees of freedom for each node
np_types = 1  # Number of proerty types
EA = 1.0e5    # Strain stiffness
nip = 1       # Number of integration points
# Out:
# 1

# %%
struct_el = :Rod
fin_el = :Line;

# %%
data = Dict(
  # Rod(nxe, np_types, nip, fin_el(nod, nodof))
  :struc_el => getfield(Main, Symbol(struct_el))(els, np_types, nip,
    getfield(Main, Symbol(fin_el))(nod, nodof)),
  :properties => [EA;],
  :x_coords => 0.0:l/els:l,
  :support => [(N, [0])],
  :loaded_nodes => [
      (1, [-0.625]),
      (2, [-1.25]),
      (3, [-1.25]),
      (4, [-1.25]),
      (5, [-0.625])
    ]
)
# Out:
# Dict{Symbol,Any} with 5 entries:
#   :support      => Tuple{Int64,Array{Int64,1}}[(5,[0])]
#   :struc_el     => CSoM.Rod(4,1,1,CSoM.Line(2,1))
#   :properties   => [100000.0]
#   :x_coords     => 0.0:0.25:1.0
#   :loaded_nodes => Tuple{Int64,Array{Float64,1}}[(1,[-0.625]),(2,[-1.25]),(3,[-…

# %%
@time m = FE4_1(data);
# Out:
# There are 4 equations and the skyline storage is 7.

# %%
using DataTables

# %%
dis_dt = DataTable(
    x_translation = m.displacements[:, 1],
)
# Out:
# 5×1 DataTables.DataTable
# │ Row │ x_translation │
# ├─────┼───────────────┤
# │ 1   │ -2.5e-5       │
# │ 2   │ -2.34375e-5   │
# │ 3   │ -1.875e-5     │
# │ 4   │ -1.09375e-5   │
# │ 5   │ 0.0           │

# %%
fm_dt = DataTable(
    normal_force_1 = m.actions[:, 1],
    normal_force_2 = m.actions[:, 2]
)
# Out:
# 4×2 DataTables.DataTable
# │ Row │ normal_force_1 │ normal_force_2 │
# ├─────┼────────────────┼────────────────┤
# │ 1   │ -0.625         │ 0.625          │
# │ 2   │ -1.875         │ 1.875          │
# │ 3   │ -3.125         │ 3.125          │
# │ 4   │ -4.375         │ 4.375          │

# %%
using Plots
gr(size=(400,500))
# Out:
# Plots.GRBackend()

# %%
x = 0.0:l/els:l
u = convert(Array, dis_dt[:x_translation])
Nf = vcat(
    convert(Array, fm_dt[:normal_force_1])[1],
    convert(Array, fm_dt[:normal_force_2])
)
# Out:
# 5-element Array{Float64,1}:
#  -0.625
#   0.625
#   1.875
#   3.125
#   4.375

# %%
p = Vector{Plots.Plot{Plots.GRBackend}}(2)
titles = ["p4.1.1 u(x)", "p4.1.1 N(x)"];

# %%
p[1]=plot(ylim=(0.0, 1.0), xlim=(0.0, 5.0),
    yflip=true, xflip=true, xlab="Normal force [N]",
    ylab="x [m]", title=titles[2]
);

# %%
vals = convert(Array, fm_dt[:normal_force_2]);

# %%
for i in 1:els
    plot!(p[1], [vals[i], vals[i]], [(i-1)*l/els, i*l/els], color=:blue,
        color=:blue, fill=true, fillalpha=0.1, leg=false)
    
    delta = abs(((i-1)*l/els) - (i*l/els)) / 20.0
    y1 = collect(((i-1)*l/els):delta:(i*l/els))
    for j in 1:length(y1)
        plot!(p[1], [vals[i], 0.0], [y1[j], y1[j]], color=:blue, alpha=0.5)
  end
end

# %%
p[2] = plot(u, x, xlim=(-0.00003, 0.0), yflip=true,
    xlab="Displacement [m]", ylab="x [m]",
    fillto=0.0, fillalpha=0.1, leg=false, title=titles[1]);

# %%
plot(p..., layout=(1, 2))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="400" height="500" viewBox="0 0 400 500">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="400" height="500"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,500 400,500 400,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="100" y="50" width="351" height="351"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 45.8815,469.674 196.063,469.674 196.063,23.3815 45.8815,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="45" y="23" width="151" height="447"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   196.063,30.0758 196.063,462.98
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   166.027,30.0758 166.027,462.98
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   135.99,30.0758 135.99,462.98
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   105.954,30.0758 105.954,462.98
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   75.9178,30.0758 75.9178,462.98
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   45.8815,30.0758 45.8815,462.98
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   193.81,23.3815 48.1342,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   193.81,112.64 48.1342,112.64
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   193.81,201.899 48.1342,201.899
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   193.81,291.157 48.1342,291.157
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   193.81,380.416 48.1342,380.416
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   193.81,469.674 48.1342,469.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   196.063,23.3815 45.8815,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   196.063,23.3815 196.063,30.0758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   166.027,23.3815 166.027,30.0758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   135.99,23.3815 135.99,30.0758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   105.954,23.3815 105.954,30.0758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   75.9178,23.3815 75.9178,30.0758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   45.8815,23.3815 45.8815,30.0758
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   196.063,23.3815 196.063,469.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   196.063,23.3815 193.81,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   196.063,112.64 193.81,112.64
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   196.063,201.899 193.81,201.899
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   196.063,291.157 193.81,291.157
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   196.063,380.416 193.81,380.416
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:1; stroke-opacity:1; fill:none" points="
#   196.063,469.674 193.81,469.674
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 196.063, 481.474)" x="196.063" y="481.474">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 166.027, 481.474)" x="166.027" y="481.474">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 135.99, 481.474)" x="135.99" y="481.474">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 105.954, 481.474)" x="105.954" y="481.474">3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 75.9178, 481.474)" x="75.9178" y="481.474">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 45.8815, 481.474)" x="45.8815" y="481.474">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.8815, 27.8815)" x="44.8815" y="27.8815">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.8815, 117.14)" x="44.8815" y="117.14">0.2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.8815, 206.399)" x="44.8815" y="206.399">0.4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.8815, 295.657)" x="44.8815" y="295.657">0.6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.8815, 384.916)" x="44.8815" y="384.916">0.8</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.8815, 474.174)" x="44.8815" y="474.174">1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; fon
